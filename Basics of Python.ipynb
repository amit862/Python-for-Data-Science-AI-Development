# %% [markdown]
# ## Basic of Python
#
# In this video we will discuss about
#
# - Various Datatypes in Python
# - Variable
# - Variables Assigment
# - Print Formatting

# %% [markdown]
# ## Various DataTypes in Python
#
# ### Numbers

# %% [markdown]
# # Python Tutorial
#
# ## Welcome to Python Tutorial
#
#
# - Datatype

# %%
1+1
# Out:
# 2

# %%
4*5
# Out:
# 20

# %%
2*10
# Out:
# 20

# %%
10/2
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %%
10**2
# Out:
# 100

# %%
##Check the Data types

# %%
type(True)
# Out:
# bool

# %%
type("Hello")
# Out:
# str

# %% [markdown]
# ### Strings

# %%
"Hello"
# Out:
# 'Hello'

# %%
'Amit Verma'
# Out:
# 'Amit Verma'

# %%
type("Amit Verma")
# Out:
# str

# %% [markdown]
# ### Variable Assigment

# %%
# syntax
# var_name=values

a=10

# %%
type(a)
# Out:
# int

# %%
a='Amit Verma'

# %%
type(a)
# Out:
# str

# %%
## Mathematical operation with Variable Assigment

a=10
b=20

# %%
print(a*b)
print(a/b)
print(a%b)
print((a*b)+(a/b)) ##BODMAS
# Out:
# 200
# 0.5
# 10
# 200.5

# %%
## Various Ways of Printing

print("Hello")
# Out:
# Hello

# %%
first_name='Amit'
last_name='Verma'

# %%
print("My first name is {} and last name is {}".format(first_name,last_name))
# Out:
# My first name is Amit and last name is Verma

# %%
print("My First name is {first} and last name is {last}".format(last=last_name,first=first_name))
# Out:
# My First name is Amit and last name is Verma

# %%
len('Amit')
# Out:
# 4

# %%
type(['1',2,3,4,5])
# Out:
# list
